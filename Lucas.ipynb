# %%
#Regressao Linear Lucas Lobato / 0050011102

# %%
import pandas as pd

# %%
from sklearn.datasets import load_boston

# %%
dataset = load_boston()

# %%
#1
df  =  pd.DataFrame(dataset.data, columns=dataset.feature_names)

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#2

# %%
df.shape
# Out:
# (506, 13)

# %%
#3

# %%
print(dataset.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
#4

# %%
print(dataset.target)
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
#5

# %%
import seaborn as sns
# %matplotlib inline
df['target'] = dataset.target
sns.pairplot(df, x_vars=['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'], y_vars='target', size=7, aspect=0.7, kind='reg')
# Out:
# C:\Users\luckl\Downloads\WPy-3670\python-3.6.7.amd64\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
#6

# %%
feature_cols = ['CRIM','ZN','INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
X = df[feature_cols]
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y = df['target']
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: target, dtype: float64

# %%
#7

# %%
print(type(X))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
#8

# %%
# Contém informações coletadas pelo Serviço de Recenseamento dos EUA sobre habitação na área de Boston. 
# Contém diferentes atributos sobre a cidade como por exemplo a taxa de criminalidade per capita por cidade,
# número médio de quartos por habitação, proporção aluno-professor por cidade e outros.

# %%
#9

# %%
from sklearn.cross_validation import train_test_split
x_train, X_test, y_train, y_test  = train_test_split(X, y, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-993a121262a4> in <module>
# ----> 1 from sklearn.cross_validation import train_test_split
#       2 x_train, X_test, y_train, y_test  = train_test_split(X, y, random_state=1)
#
# ModuleNotFoundError: No module named 'sklearn.cross_validation'

# %%
#11

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-8e15ffdce804> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 linreg = LinearRegression()
# ----> 3 linreg.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
#12

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-12ce92a3cce0> in <module>
# ----> 1 print(linreg.intercept_)
#       2 print(linreg.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
#13

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-12ce92a3cce0> in <module>
# ----> 1 print(linreg.intercept_)
#       2 print(linreg.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
#14

# %%
#16-Existe uma forma de melhorar essa margem para que fique menor? Se sim, como seria?
#sim, treinando X e y apenas com features que apresentarem maior proximidade na reta no gráfico.
